# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
trainX = np.genfromtxt("data/preprocessed_for_learning/X_train.csv", dtype=float, delimiter=',', skip_header=1)
trainy = np.genfromtxt("data/preprocessed_for_learning/y_train.csv", dtype=float, delimiter=',', skip_header=1)
testX = np.genfromtxt("data/preprocessed_for_learning/X_test.csv", dtype=float, delimiter=',', skip_header=1)
testy = np.genfromtxt("data/preprocessed_for_learning/y_test.csv", dtype=float, delimiter=',', skip_header=1)

# %%
rfc = RandomForestClassifier()
rfc.fit(trainX, trainy)
# make predictions
yhat = rfc.predict(testX)
# evaluate predictions
accuracy = accuracy_score(testy, yhat)
# Out:
# C:\Users\slise\AppData\Roaming\Python\Python37\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
accuracy
# Out:
# 0.8130841121495327

# %%
from sklearn_porter import Porter
porter = Porter(rfc, language='JS')
output = porter.export(embed_data=True)
print(output)
# Out:
# var RandomForestClassifier = function() {
#
#     var findMax = function(nums) {
#         var index = 0;
#         for (var i = 0; i < nums.length; i++) {
#             index = nums[i] > nums[index] ? i : index;
#         }
#         return index;
#     };
#
#     var trees = new Array();
#
#     trees.push(function(features) {
#         var classes = new Array(4);
#
#         if (features[2] <= 0.9854544699192047) {
#             if (features[7] <= 0.043161649256944656) {
#                 if (features[3] <= 0.045516843907535076) {
#                     if (features[2] <= 0.899201363325119) {
#                         if (features[2] <= 0.8980796337127686) {
#                             classes[0] = 14;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         classes[0] = 81;
#                         classes[1] = 0;
#                         classes[2] = 0;
#                         classes[3] = 0;
#                     }
#                 } else {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 3;
#                     classes[3] = 0;
#                 }
#             } else {
#                 if (features[8] <= 0.07504379749298096) {
#                     if (features[4] <= 0.2881218492984772) {
#                         if (features[6] <= 0.24530553817749023) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 22;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 2;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (features[3] <= 0.25393007695674896) {
#                             if (features[7] <= 0.1418723165988922) {
#                                 if (features[3] <= -0.09835762903094292) {
#                                     classes[0] = 0;
#                                     classes[1] = 17;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[7] <= 0.07588939368724823) {
#                                         if (features[7] <= 0.05876053869724274) {
#                                             if (features[2] <= 0.9336168467998505) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 10;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 1;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             if (features[6] <= 0.07515237852931023) {
#                                                 classes[0] = 7;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 if (features[3] <= -0.014120033476501703) {
#                                                     classes[0] = 3;
#                                                     classes[1] = 0;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 3;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 }
#                                             }
#                                         }
#                                     } else {
#                                         if (features[6] <= 0.13332851976156235) {
#                                             if (features[4] <= 0.3488653302192688) {
#                                                 if (features[2] <= 0.9219761192798615) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 1;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 6;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 30;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             if (features[6] <= 0.1817767694592476) {
#                                                 if (features[0] <= 0.1539296805858612) {
#                                                     if (features[5] <= 0.8702032566070557) {
#                                                         classes[0] = 0;
#                                                         classes[1] = 4;
#                                                         classes[2] = 0;
#                                                         classes[3] = 0;
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 0;
#                                                         classes[2] = 5;
#                                                         classes[3] = 0;
#                                                     }
#                                                 } else {
#                                                     if (features[2] <= 0.8679620027542114) {
#                                                         if (features[3] <= 0.029296569526195526) {
#                                                             classes[0] = 0;
#                                                             classes[1] = 0;
#                                                             classes[2] = 2;
#                                                             classes[3] = 0;
#                                                         } else {
#                                                             classes[0] = 0;
#                                                             classes[1] = 3;
#                                                             classes[2] = 0;
#                                                             classes[3] = 0;
#                                                         }
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 9;
#                                                         classes[2] = 0;
#                                                         classes[3] = 0;
#                                                     }
#                                                 }
#                                             } else {
#                                                 if (features[0] <= 0.22957143932580948) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 5;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 2;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (features[5] <= 0.9119139611721039) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 7;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 3;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     if (features[6] <= 0.08383376896381378) {
#                         if (features[4] <= 0.5482747405767441) {
#                             classes[0] = 0;
#                             classes[1] = 3;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 1;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (features[8] <= 0.10339628905057907) {
#                             if (features[8] <= 0.09665373340249062) {
#                                 if (features[8] <= 0.08311101421713829) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 22;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[0] <= 0.20209646970033646) {
#                                         classes[0] = 0;
#                                         classes[1] = 1;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 9;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 2;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 49;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             }
#         } else {
#             classes[0] = 0;
#             classes[1] = 0;
#             classes[2] = 0;
#             classes[3] = 97;
#         }
#
#         return findMax(classes);
#     });
#
#     trees.push(function(features) {
#         var classes = new Array(4);
#
#         if (features[4] <= 0.03605427115689963) {
#             classes[0] = 0;
#             classes[1] = 0;
#             classes[2] = 0;
#             classes[3] = 108;
#         } else {
#             if (features[5] <= 0.8672462701797485) {
#                 if (features[5] <= 0.7442737519741058) {
#                     classes[0] = 0;
#                     classes[1] = 0;
#                     classes[2] = 20;
#                     classes[3] = 0;
#                 } else {
#                     if (features[7] <= 0.1275164857506752) {
#                         if (features[0] <= 0.14241177588701248) {
#                             if (features[3] <= -0.02140364225488156) {
#                                 classes[0] = 7;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (features[6] <= 0.1459887996315956) {
#                                 classes[0] = 0;
#                                 classes[1] = 10;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 if (features[5] <= 0.8444820046424866) {
#                                     if (features[0] <= 0.39745257794857025) {
#                                         classes[0] = 0;
#                                         classes[1] = 3;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 1;
#                                         classes[3] = 0;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 4;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         if (features[6] <= 0.14423517882823944) {
#                             if (features[7] <= 0.1512707844376564) {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 6;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 27;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             } else {
#                 if (features[0] <= 0.142162524163723) {
#                     if (features[0] <= 0.08875714614987373) {
#                         if (features[4] <= 0.3249388039112091) {
#                             if (features[8] <= 0.0260553820990026) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 2;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (features[7] <= 0.06922993250191212) {
#                                 if (features[1] <= 0.43404334783554077) {
#                                     if (features[3] <= 0.03231447841972113) {
#                                         classes[0] = 40;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[2] <= 0.928638756275177) {
#                                             classes[0] = 1;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 1;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     if (features[4] <= 0.43551531434059143) {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[8] <= 0.025631568394601345) {
#                                             classes[0] = 9;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             if (features[0] <= 0.07731087505817413) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 2;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 2;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (features[7] <= 0.0929153747856617) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 1;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 3;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         if (features[0] <= 0.13748906552791595) {
#                             if (features[8] <= 0.025246107019484043) {
#                                 if (features[7] <= 0.050098538398742676) {
#                                     if (features[3] <= 0.029138104990124702) {
#                                         classes[0] = 27;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[6] <= 0.07061037421226501) {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 2;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 2;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 if (features[7] <= 0.163786418735981) {
#                                     if (features[7] <= 0.07207173481583595) {
#                                         if (features[0] <= 0.10884415358304977) {
#                                             classes[0] = 4;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 6;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 35;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 5;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         } else {
#                             classes[0] = 7;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     if (features[7] <= 0.113413505256176) {
#                         if (features[4] <= 0.2217458412051201) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 3;
#                             classes[3] = 0;
#                         } else {
#                             if (features[3] <= -0.14336206763982773) {
#                                 if (features[7] <= 0.05259806476533413) {
#                                     classes[0] = 6;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[1] <= 0.41062839329242706) {
#                                         classes[0] = 0;
#                                         classes[1] = 3;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 2;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             } else {
#                                 if (features[7] <= 0.061429524794220924) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[0] <= 0.15494433045387268) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 1;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[5] <= 0.8848260045051575) {
#                                             if (features[3] <= -0.02457496547140181) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 0;
#                                                 classes[2] = 1;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 4;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 18;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#                     } else {
#                         if (features[6] <= 0.13697992265224457) {
#                             if (features[8] <= 0.038803287781775) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             } else {
#                                 if (features[2] <= 0.8887408375740051) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 1;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 4;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         } else {
#                             if (features[4] <= 0.35214634239673615) {
#                                 if (features[6] <= 0.19993682205677032) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 21;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[0] <= 0.21830055117607117) {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 11;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             } else {
#                                 if (features[1] <= 0.41937869787216187) {
#                                     if (features[0] <= 0.1600174680352211) {
#                                         classes[0] = 0;
#                                         classes[1] = 1;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 1;
#                                         classes[3] = 0;
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 3;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     }
#                 }
#             }
#         }
#
#         return findMax(classes);
#     });
#
#     trees.push(function(features) {
#         var classes = new Array(4);
#
#         if (features[4] <= 0.03605427115689963) {
#             classes[0] = 0;
#             classes[1] = 0;
#             classes[2] = 0;
#             classes[3] = 94;
#         } else {
#             if (features[3] <= -0.031254593282938004) {
#                 if (features[6] <= 0.0746447928249836) {
#                     if (features[6] <= 0.03207218647003174) {
#                         if (features[5] <= 0.9557131230831146) {
#                             classes[0] = 53;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 1;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (features[8] <= 0.02679726667702198) {
#                             if (features[4] <= 0.46385525166988373) {
#                                 classes[0] = 37;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (features[0] <= 0.10914827510714531) {
#                                 if (features[2] <= 0.8931118547916412) {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[3] <= -0.07314388826489449) {
#                                         classes[0] = 0;
#                                         classes[1] = 2;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 3;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 7;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         }
#                     }
#                 } else {
#                     if (features[0] <= 0.13623448461294174) {
#                         if (features[8] <= 0.02102157613262534) {
#                             classes[0] = 3;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             if (features[2] <= 0.9437926411628723) {
#                                 classes[0] = 0;
#                                 classes[1] = 14;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             }
#                         }
#                     } else {
#                         if (features[5] <= 0.911765456199646) {
#                             if (features[6] <= 0.12233772873878479) {
#                                 if (features[5] <= 0.909592866897583) {
#                                     if (features[7] <= 0.10188161954283714) {
#                                         classes[0] = 0;
#                                         classes[1] = 5;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[7] <= 0.15896881744265556) {
#                                             classes[0] = 1;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 1;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 3;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 11;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             if (features[7] <= 0.1292983628809452) {
#                                 classes[0] = 0;
#                                 classes[1] = 4;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             }
#                         }
#                     }
#                 }
#             } else {
#                 if (features[8] <= 0.052654366940259933) {
#                     if (features[8] <= 0.01868234295397997) {
#                         if (features[1] <= 0.4132903665304184) {
#                             classes[0] = 13;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         } else {
#                             if (features[6] <= 0.07061037421226501) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 1;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         }
#                     } else {
#                         if (features[3] <= 0.17090505361557007) {
#                             if (features[1] <= 0.25010543316602707) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 5;
#                                 classes[3] = 0;
#                             } else {
#                                 if (features[4] <= 0.4425349831581116) {
#                                     if (features[6] <= 0.1673402115702629) {
#                                         if (features[0] <= 0.05675983987748623) {
#                                             if (features[7] <= 0.07915879786014557) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 0;
#                                                 classes[2] = 1;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 1;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             if (features[1] <= 0.4208863526582718) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 25;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 if (features[4] <= 0.41732412576675415) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 1;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 8;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 }
#                                             }
#                                         }
#                                     } else {
#                                         if (features[7] <= 0.14972087740898132) {
#                                             classes[0] = 0;
#                                             classes[1] = 6;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 2;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     if (features[4] <= 0.4595201164484024) {
#                                         classes[0] = 4;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 3;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 5;
#                             classes[3] = 0;
#                         }
#                     }
#                 } else {
#                     if (features[8] <= 0.10384271666407585) {
#                         if (features[0] <= 0.17591451853513718) {
#                             if (features[5] <= 0.9015257358551025) {
#                                 if (features[8] <= 0.05450478754937649) {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 } else {
#                                     if (features[4] <= 0.3958602696657181) {
#                                         if (features[0] <= 0.11939138546586037) {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 1;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 4;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 8;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             } else {
#                                 if (features[3] <= -0.018086991738528013) {
#                                     classes[0] = 0;
#                                     classes[1] = 2;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 5;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         } else {
#                             if (features[5] <= 0.8490623235702515) {
#                                 if (features[7] <= 0.13996165245771408) {
#                                     classes[0] = 0;
#                                     classes[1] = 7;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 2;
#                                     classes[3] = 0;
#                                 }
#                             } else {
#                                 if (features[8] <= 0.05356083996593952) {
#                                     classes[0] = 0;
#                                     classes[1] = 1;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 0;
#                                     classes[2] = 24;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     } else {
#                         if (features[6] <= 0.13006454706192017) {
#                             if (features[2] <= 0.7673320472240448) {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 9;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 41;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             }
#         }
#
#         return findMax(classes);
#     });
#
#     trees.push(function(features) {
#         var classes = new Array(4);
#
#         if (features[4] <= 0.03605427115689963) {
#             classes[0] = 0;
#             classes[1] = 0;
#             classes[2] = 0;
#             classes[3] = 101;
#         } else {
#             if (features[7] <= 0.047293880954384804) {
#                 if (features[1] <= 0.4205622375011444) {
#                     classes[0] = 83;
#                     classes[1] = 0;
#                     classes[2] = 0;
#                     classes[3] = 0;
#                 } else {
#                     if (features[2] <= 0.8949684202671051) {
#                         if (features[3] <= 0.04429563274607062) {
#                             if (features[8] <= 0.025635449215769768) {
#                                 classes[0] = 11;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 0;
#                                 classes[1] = 1;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
# ...
#                                 }
#                             }
#                         }
#                     } else {
#                         if (features[7] <= 0.052135342732071877) {
#                             if (features[5] <= 0.8285183310508728) {
#                                 classes[0] = 0;
#                                 classes[1] = 4;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             } else {
#                                 classes[0] = 1;
#                                 classes[1] = 0;
#                                 classes[2] = 0;
#                                 classes[3] = 0;
#                             }
#                         } else {
#                             classes[0] = 8;
#                             classes[1] = 0;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             } else {
#                 if (features[8] <= 0.10390741750597954) {
#                     if (features[6] <= 0.13280003517866135) {
#                         if (features[0] <= 0.3018270432949066) {
#                             if (features[3] <= -0.014120033476501703) {
#                                 if (features[6] <= 0.07967309281229973) {
#                                     if (features[1] <= 0.43864597380161285) {
#                                         if (features[7] <= 0.09494135156273842) {
#                                             classes[0] = 1;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 2;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 5;
#                                         classes[1] = 0;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 } else {
#                                     if (features[4] <= 0.2812998592853546) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 2;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[2] <= 0.8877520561218262) {
#                                             if (features[4] <= 0.42609283328056335) {
#                                                 classes[0] = 2;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 if (features[7] <= 0.06502290070056915) {
#                                                     classes[0] = 1;
#                                                     classes[1] = 0;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     if (features[7] <= 0.13331177458167076) {
#                                                         classes[0] = 0;
#                                                         classes[1] = 3;
#                                                         classes[2] = 0;
#                                                         classes[3] = 0;
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 0;
#                                                         classes[2] = 1;
#                                                         classes[3] = 0;
#                                                     }
#                                                 }
#                                             }
#                                         } else {
#                                             if (features[7] <= 0.035343876108527184) {
#                                                 classes[0] = 1;
#                                                 classes[1] = 0;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 16;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         }
#                                     }
#                                 }
#                             } else {
#                                 if (features[8] <= 0.05661578290164471) {
#                                     if (features[2] <= 0.9361197352409363) {
#                                         classes[0] = 0;
#                                         classes[1] = 28;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[1] <= 0.3047628253698349) {
#                                             classes[0] = 0;
#                                             classes[1] = 4;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             classes[0] = 1;
#                                             classes[1] = 0;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     if (features[2] <= 0.9213229119777679) {
#                                         if (features[7] <= 0.1411335989832878) {
#                                             classes[0] = 0;
#                                             classes[1] = 8;
#                                             classes[2] = 0;
#                                             classes[3] = 0;
#                                         } else {
#                                             if (features[2] <= 0.8848894536495209) {
#                                                 classes[0] = 0;
#                                                 classes[1] = 3;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 0;
#                                                 classes[2] = 3;
#                                                 classes[3] = 0;
#                                             }
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 2;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             }
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 2;
#                             classes[3] = 0;
#                         }
#                     } else {
#                         if (features[7] <= 0.15120330452919006) {
#                             if (features[1] <= 0.2490578144788742) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 2;
#                                 classes[3] = 0;
#                             } else {
#                                 if (features[3] <= -0.011986711528152227) {
#                                     if (features[7] <= 0.08564437925815582) {
#                                         classes[0] = 0;
#                                         classes[1] = 0;
#                                         classes[2] = 3;
#                                         classes[3] = 0;
#                                     } else {
#                                         if (features[4] <= 0.41560980677604675) {
#                                             if (features[3] <= -0.023578195832669735) {
#                                                 if (features[7] <= 0.1327827051281929) {
#                                                     if (features[8] <= 0.07374396175146103) {
#                                                         classes[0] = 0;
#                                                         classes[1] = 9;
#                                                         classes[2] = 0;
#                                                         classes[3] = 0;
#                                                     } else {
#                                                         classes[0] = 0;
#                                                         classes[1] = 0;
#                                                         classes[2] = 1;
#                                                         classes[3] = 0;
#                                                     }
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 1;
#                                                     classes[3] = 0;
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 0;
#                                                 classes[2] = 1;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 2;
#                                             classes[3] = 0;
#                                         }
#                                     }
#                                 } else {
#                                     if (features[2] <= 0.8929527103900909) {
#                                         if (features[2] <= 0.8848561346530914) {
#                                             if (features[7] <= 0.0929594337940216) {
#                                                 if (features[3] <= 0.09591850265860558) {
#                                                     classes[0] = 0;
#                                                     classes[1] = 0;
#                                                     classes[2] = 1;
#                                                     classes[3] = 0;
#                                                 } else {
#                                                     classes[0] = 0;
#                                                     classes[1] = 2;
#                                                     classes[2] = 0;
#                                                     classes[3] = 0;
#                                                 }
#                                             } else {
#                                                 classes[0] = 0;
#                                                 classes[1] = 7;
#                                                 classes[2] = 0;
#                                                 classes[3] = 0;
#                                             }
#                                         } else {
#                                             classes[0] = 0;
#                                             classes[1] = 0;
#                                             classes[2] = 2;
#                                             classes[3] = 0;
#                                         }
#                                     } else {
#                                         classes[0] = 0;
#                                         classes[1] = 10;
#                                         classes[2] = 0;
#                                         classes[3] = 0;
#                                     }
#                                 }
#                             }
#                         } else {
#                             if (features[7] <= 0.166826494038105) {
#                                 classes[0] = 0;
#                                 classes[1] = 0;
#                                 classes[2] = 11;
#                                 classes[3] = 0;
#                             } else {
#                                 if (features[2] <= 0.8978158831596375) {
#                                     classes[0] = 2;
#                                     classes[1] = 0;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 } else {
#                                     classes[0] = 0;
#                                     classes[1] = 1;
#                                     classes[2] = 0;
#                                     classes[3] = 0;
#                                 }
#                             }
#                         }
#                     }
#                 } else {
#                     if (features[4] <= 0.5056723058223724) {
#                         classes[0] = 0;
#                         classes[1] = 0;
#                         classes[2] = 52;
#                         classes[3] = 0;
#                     } else {
#                         if (features[5] <= 0.776707798242569) {
#                             classes[0] = 0;
#                             classes[1] = 0;
#                             classes[2] = 4;
#                             classes[3] = 0;
#                         } else {
#                             classes[0] = 0;
#                             classes[1] = 1;
#                             classes[2] = 0;
#                             classes[3] = 0;
#                         }
#                     }
#                 }
#             }
#         }
#
#         return findMax(classes);
#     });
#
#     this.predict = function(features) {
#         var classes = new Array(4).fill(0);
#         for (var i = 0; i < trees.length; i++) {
#             classes[trees[i](features)]++;
#         }
#         return findMax(classes);
#     }
#
# };
#
# if (typeof process !== 'undefined' && typeof process.argv !== 'undefined') {
#     if (process.argv.length - 2 == 9) {
#
#         // Features:
#         var features = process.argv.slice(2);
#
#         // Prediction:
#         var prediction = new RandomForestClassifier().predict(features);
#         console.log(prediction);
#
#     }
# }

# %%
file1 = open("model.js","a") 
file1.write(output)
file1.close()
